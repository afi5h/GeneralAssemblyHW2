# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 20px; height: 55px">
#
# # Project 2: Analyzing IMDb Data
#
# _Author: Kevin Markham (DC)_
#
# ---

# %% [markdown]
# For project two, you will complete a series of exercises exploring movie rating data from IMDb.
#
# For these exercises, you will be conducting basic exploratory data analysis on IMDB's movie data, looking to answer such questions as:
#
# What is the average rating per genre?
# How many different actors are in a movie?
#
# This process will help you practice your data analysis skills while becoming comfortable with Pandas.

# %% [markdown]
# ## Basic level

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# #### Read in 'imdb_1000.csv' and store it in a DataFrame named movies.

# %%
movies = pd.read_csv('./data/imdb_1000.csv')
movies.head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %% [markdown]
# #### Check the number of rows and columns.

# %%
# Answer:
movies.shape
# Out:
# (979, 6)

# %% [markdown]
# #### Check the data type of each column.

# %%
# Answer:
movies.dtypes
# Out:
# star_rating       float64
# title              object
# content_rating     object
# genre              object
# duration            int64
# actors_list        object
# dtype: object

# %% [markdown]
# #### Calculate the average movie duration.

# %%
# Answer:
movies.duration.mean()
# Out:
# 120.97957099080695

# %% [markdown]
# #### Sort the DataFrame by duration to find the shortest and longest movies.

# %%
# Answer:
movies.loc[:,'duration'].sort_values()
# Out:
# 389     64
# 338     66
# 258     67
# 293     68
# 88      68
# 742     69
# 351     70
# 938     75
# 405     75
# 303     76
# 713     78
# 864     78
# 489     78
# 535     79
# 513     80
# 853     80
# 533     80
# 283     80
# 297     80
# 622     80
# 117     81
# 541     81
# 738     81
# 789     81
# 330     81
# 595     82
# 306     82
# 174     83
# 759     83
# 766     83
#       ...
# 361    181
# 166    182
# 109    183
# 245    184
# 132    186
# 611    187
# 318    188
# 184    188
# 89     189
# 316    189
# 40     189
# 671    191
# 220    191
# 424    193
# 620    194
# 8      195
# 385    197
# 335    197
# 2      200
# 7      201
# 630    202
# 767    205
# 17     207
# 204    212
# 85     216
# 445    220
# 142    224
# 78     229
# 157    238
# 476    242
# Name: duration, Length: 979, dtype: int64

# %% [markdown]
# #### Create a histogram of duration, choosing an "appropriate" number of bins.

# %%
# Answer:
ax = movies.loc[:,'duration'].plot(kind='hist',bins=30);

# %% [markdown]
# #### Use a box plot to display that same data.

# %%
# Answer:
ax = movies.loc[:,'duration'].plot(kind='box');

# %% [markdown]
# ## Intermediate level

# %% [markdown]
# #### Count how many movies have each of the content ratings.

# %%
# Answer:
movies.loc[:,'content_rating'].value_counts()
# Out:
# R            460
# PG-13        189
# PG           123
# NOT RATED     65
# APPROVED      47
# UNRATED       38
# G             32
# PASSED         7
# NC-17          7
# X              4
# GP             3
# TV-MA          1
# Name: content_rating, dtype: int64

# %% [markdown]
# #### Use a visualization to display that same data, including a title and x and y labels.

# %%
# Answer:
ax = movies.loc[:,'content_rating'].value_counts().plot(kind='bar')
ax.set_title('Movie Count by Content Rating')
ax.set_ylabel('Movie Count')
ax.set_xlabel('Content Rating')
# Out:
# Text(0.5,0,'Content Rating')

# %% [markdown]
# #### Convert the following content ratings to "UNRATED": NOT RATED, APPROVED, PASSED, GP.

# %%
# Answer:
movies.replace('NOT RATED','UNRATED')
movies.replace('APPROVED','UNRATED')
movies.replace('PASSED','UNRATED')
movies.replace('GP','UNRATED')
# Out:
#      star_rating                                              title  \
# 0            9.3                           The Shawshank Redemption
# 1            9.2                                      The Godfather
# 2            9.1                             The Godfather: Part II
# 3            9.0                                    The Dark Knight
# 4            8.9                                       Pulp Fiction
# 5            8.9                                       12 Angry Men
# 6            8.9                     The Good, the Bad and the Ugly
# 7            8.9      The Lord of the Rings: The Return of the King
# 8            8.9                                   Schindler's List
# 9            8.9                                         Fight Club
# 10           8.8  The Lord of the Rings: The Fellowship of the Ring
# 11           8.8                                          Inception
# 12           8.8     Star Wars: Episode V - The Empire Strikes Back
# ...

# %% [markdown]
# #### Convert the following content ratings to "NC-17": X, TV-MA.

# %%
# Answer:
movies.replace('X','NC-17')
movies.replace('TV-MA','NC-17')
# Out:
#      star_rating                                              title  \
# 0            9.3                           The Shawshank Redemption
# 1            9.2                                      The Godfather
# 2            9.1                             The Godfather: Part II
# 3            9.0                                    The Dark Knight
# 4            8.9                                       Pulp Fiction
# 5            8.9                                       12 Angry Men
# 6            8.9                     The Good, the Bad and the Ugly
# 7            8.9      The Lord of the Rings: The Return of the King
# 8            8.9                                   Schindler's List
# 9            8.9                                         Fight Club
# 10           8.8  The Lord of the Rings: The Fellowship of the Ring
# 11           8.8                                          Inception
# 12           8.8     Star Wars: Episode V - The Empire Strikes Back
# ...

# %% [markdown]
# #### Count the number of missing values in each column.

# %%
# Answer:
movies.isnull().sum()
# Out:
# star_rating       0
# title             0
# content_rating    3
# genre             0
# duration          0
# actors_list       0
# dtype: int64

# %% [markdown]
# #### If there are missing values: examine them, then fill them in with "reasonable" values.

# %%
# Answer:
movies.loc[ (movies['content_rating'].isnull()==True ) , : ]

movies.loc[:,'content_rating'].fillna(value='R',inplace=True)

# %% [markdown]
# #### Calculate the average star rating for movies 2 hours or longer, and compare that with the average star rating for movies shorter than 2 hours.

# %%
# Answer:
twohoursormore = movies.loc[ (movies['duration']>=120) , 'star_rating' ].mean()
lessthantwohours = movies.loc[ (movies['duration']<120) , 'star_rating' ].mean()

print(twohoursormore)
print(lessthantwohours)
# Out:
# 7.948898678414082
# 7.838666666666657

# %% [markdown]
# #### Use a visualization to detect whether there is a relationship between duration and star rating.

# %%
# Answer:
import seaborn as sns
ax = sns.heatmap(movies.corr(), vmin=-1, vmax=1, cmap=sns.diverging_palette(h_neg=220, h_pos=10, n=21))

# %% [markdown]
# #### Calculate the average duration for each genre.

# %%
# Answer:
movies.groupby('genre')['duration'].mean()
# Out:
# genre
# Action       126.485294
# Adventure    134.840000
# Animation     96.596774
# Biography    131.844156
# Comedy       107.602564
# Crime        122.298387
# Drama        126.539568
# Family       107.500000
# Fantasy      112.000000
# Film-Noir     97.333333
# History       66.000000
# Horror       102.517241
# Mystery      115.625000
# Sci-Fi       109.000000
# Thriller     114.200000
# Western      136.666667
# Name: duration, dtype: float64

# %% [markdown]
# ## Advanced level

# %% [markdown]
# #### Visualize the relationship between content rating and duration.

# %%
# Answer:
ax = movies.groupby('content_rating')['duration'].mean().plot(kind='bar')
ax.set_title('Average Movie Duration by Content Rating')
ax.set_ylabel('Average Movie Duration')
ax.set_xlabel('Content Rating')
# Out:
# Text(0.5,0,'Content Rating')

# %% [markdown]
# #### Determine the top rated movie (by star rating) for each genre.

# %%
# Answer:
movies.groupby('genre')['star_rating'].max()
# Out:
# genre
# Action       9.0
# Adventure    8.9
# Animation    8.6
# Biography    8.9
# Comedy       8.6
# Crime        9.3
# Drama        8.9
# Family       7.9
# Fantasy      7.7
# Film-Noir    8.3
# History      8.0
# Horror       8.6
# Mystery      8.6
# Sci-Fi       8.2
# Thriller     8.0
# Western      8.9
# Name: star_rating, dtype: float64

# %% [markdown]
# #### Check if there are multiple movies with the same title, and if so, determine if they are actually duplicates.

# %%
# Answer:
movies.loc[:,'title'].value_counts()>1
print(movies.loc[ ( movies['title'] == 'Les Miserables'  ), :])
print(movies.loc[ ( movies['title'] == 'The Girl with the Dragon Tattoo'  ), :])
print(movies.loc[ ( movies['title'] == 'Dracula'  ), :])
print(movies.loc[ ( movies['title'] == 'True Grit'  ), :])
#Not duplicates,remakes.
#The underlying characteristics are different (cast, ratings, duration)
# Out:
#      star_rating           title content_rating  genre  duration  \
# 678          7.7  Les Miserables          PG-13  Drama       158
# 924          7.5  Les Miserables          PG-13  Crime       134
#
#                                            actors_list
# 678  [u'Hugh Jackman', u'Russell Crowe', u'Anne Hat...
# 924  [u'Liam Neeson', u'Geoffrey Rush', u'Uma Thurm...
#      star_rating                            title content_rating  genre  \
# 466          7.9  The Girl with the Dragon Tattoo              R  Crime
# 482          7.8  The Girl with the Dragon Tattoo              R  Crime
#
#      duration                                        actors_list
# 466       158  [u'Daniel Craig', u'Rooney Mara', u'Christophe...
# 482       152  [u'Michael Nyqvist', u'Noomi Rapace', u'Ewa Fr...
#      star_rating    title content_rating   genre  duration  \
# 703          7.6  Dracula       APPROVED  Horror        85
# 905          7.5  Dracula              R  Horror       128
#
# ...

# %% [markdown]
# #### Calculate the average star rating for each genre, but only include genres with at least 10 movies

# %% [markdown]
# **You only need to choose one of the options below.** However, solving for multiple options would count as "extra credit" that could e.g. raise your score from a 2 ("meets expectations") to a 3 ("exceeds expectations").

# %% [markdown]
# #### Option 1: manually create a list of relevant genres, then filter using that list

# %%
# Answer:
movies.loc[:,'genre'].value_counts()>=10

mymovies = (
   movies.loc[     (movies.loc[:,'genre'] == 'Drama') 
                  | (movies.loc[:,'genre'] == 'Comedy') 
                  | (movies.loc[:,'genre'] == 'Action')
                  | (movies.loc[:,'genre'] == 'Crime')
                  | (movies.loc[:,'genre'] == 'Biography')
                  | (movies.loc[:,'genre'] == 'Adventure')
                  | (movies.loc[:,'genre'] == 'Animation')
                  | (movies.loc[:,'genre'] == 'Horror')
                  | (movies.loc[:,'genre'] == 'Mystery')
    ,:]
)

mymovies.groupby('genre')['star_rating'].mean()
# Out:
# genre
# Action       7.884559
# Adventure    7.933333
# Animation    7.914516
# Biography    7.862338
# Comedy       7.822436
# Crime        7.916935
# Drama        7.902518
# Horror       7.806897
# Mystery      7.975000
# Name: star_rating, dtype: float64

# %% [markdown]
# #### Option 2: automatically create a list of relevant genres by saving the value_counts and then filtering

# %%
# Answer:

# %% [markdown]
# #### Option 3: calculate the average star rating for all genres, then filter using a boolean Series

# %%
# Answer:

movies.groupby('genre')['star_rating'].mean()
# Out:
# genre
# Action       7.884559
# Adventure    7.933333
# Animation    7.914516
# Biography    7.862338
# Comedy       7.822436
# Crime        7.916935
# Drama        7.902518
# Family       7.850000
# Fantasy      7.700000
# Film-Noir    8.033333
# History      8.000000
# Horror       7.806897
# Mystery      7.975000
# Sci-Fi       7.920000
# Thriller     7.680000
# Western      8.255556
# Name: star_rating, dtype: float64

# %% [markdown]
# #### Option 4: aggregate by count and mean, then filter using the count

# %%
# Answer:

# %% [markdown]
# ## Bonus

# %% [markdown]
# #### Figure out something "interesting" using the actors data!
